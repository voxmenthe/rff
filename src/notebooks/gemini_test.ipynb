# %%
from google import genai
from google.genai import types
import pathlib
import httpx
import argparse
import os
#from pypdf import PdfReader, PdfWriter
from io import BytesIO

# Load GEMINI_API_KEY from .env file
# Consider using python-dotenv if you want to load from a .env file automatically
# from dotenv import load_dotenv
# load_dotenv()
GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')

# Initialize Gemini Client globally
# This requires GEMINI_API_KEY to be set before this script block is executed.
if not GEMINI_API_KEY:
    raise ValueError("GEMINI_API_KEY not found in environment variables. Please set it before running the script.")
client = genai.Client(api_key=GEMINI_API_KEY)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
prompt_text = "Explain a random system design problem. (random_seed = 42)"
gemini_model_name = "gemini-2.5-flash-preview-05-20"
response = client.models.generate_content(
    model=gemini_model_name,
    contents=[
    #     types.Part.from_bytes(data=subset_pdf_bytes_data, mime_type="application/pdf"),
    prompt_text
    ]
)

# %%
print(response.text)
# Out:
# Okay, let's conjure a system design problem for you with `random_seed = 42`.
#
# ---
#
# ### Random System Design Problem: **The "CodeArena" Automated Peer-Review & Grading Platform**
#
# **Problem Statement:**
#
# Design a scalable, reliable, and secure online platform called "CodeArena." Its primary purpose is to allow students to submit programming assignments, have them automatically graded, and also facilitate a **peer-review mechanism** where students review each other's code.
#
# **Core Challenge:** The unique blend of automated grading, a robust and secure code execution environment, and a structured peer-review workflow with fairness mechanisms.
#
# ---
#
# **I. Functional Requirements:**
#
# 1.  **User Management:**
#     *   Students can register, log in, and manage their profiles.
#     *   Instructors can register, log in, create courses, manage assignments, and view student progress/submissions.
#     *   Admins (optional, for system-level management).
# 2.  **Course & Assignment Management:**
#     *   Instructors can create courses, add students to courses (or generate invite links).
#     *   Instructors can create assignments:
#         *   Define problem statements (markdown support).
#         *   Specify allowed programming languages (e.g., Python, Java, C++).
#         *   Upload public test cases (visible to students).
#         *   Upload private/hidden test cases (for final grading).
#         *   Set submission deadlines, grading criteria, and peer-review windows.
#         *   Define peer-review rubric.
# 3.  **Code Submission:**
#     *   Students can submit code files for a given assignment.
#     *   Support for multiple submissions; only the latest or best-scoring submission counts.
#     *   Real-time syntax highlighting in the submission editor.
#     *   Basic code linting/formatting (optional, but a nice-to-have).
# 4.  **Automated Grading Engine:**
#     *   Execute submitted code against public and private test cases.
#     *   Run tests in a secure, isolated sandbox environment (prevent malicious code, infinite loops, resource hogging).
#     *   Capture `stdout`, `stderr`, and execution time/memory usage.
#     *   Provide immediate feedback to students on public test cases (pass/fail, output diff, runtime errors).
#     *   Final grading against private test cases upon deadline or instructor trigger.
#     *   Support for different test types (unit tests, performance tests).
# 5.  **Peer Review System:**
#     *   After submission, students are assigned a set number of *anonymous* peer submissions to review (e.g., 3 submissions per student).
#     *   Students review code based on instructor-defined rubrics (e.g., code style, correctness, efficiency, comments).
#     *   Reviewers can add comments directly to lines of code.
#     *   Mechanism to flag inappropriate reviews or malicious code during review.
#     *   Students can see their own reviews (after the review period ends or final grades are released).
#     *   Instructors can monitor review progress and validity.
#     *   Fairness mechanism: Reviewers might be graded on the quality/consistency of their reviews.
# 6.  **Results & Analytics:**
#     *   Students can view their scores, detailed test case results, and peer review feedback.
#     *   Instructors can view aggregated course statistics, individual student scores, submission history, and peer-review reports.
#     *   Export capabilities for grades and submission data.
# 7.  **Notifications:**
#     *   Notify students about assignment deadlines, new assignments, grading completion, and peer-review assignments.
#     *   Notify instructors about new submissions, overdue reviews.
#
# **II. Non-Functional Requirements:**
#
# 1.  **Scalability:**
#     *   Support thousands of courses and hundreds of thousands of students.
#     *   Handle peak load during assignment deadlines (many concurrent submissions and grading requests).
#     *   Efficiently scale the automated grading infrastructure up and down.
# 2.  **Reliability & Availability:**
#     *   High availability (e.g., 99.9% uptime). Submissions must not be lost.
#     *   Robust error handling for grading failures (e.g., re-queuing failed jobs).
# 3.  **Performance:**
#     *   Low latency for code submission and feedback on public test cases (e.g., < 5 seconds for typical problems).
#     *   Peer review UI should be responsive.
# 4.  **Security:**
#     *   **Critical:** Code execution sandboxing to prevent students from accessing underlying system resources, network, or other students' data.
#     *   Protect student and instructor data (PII, code solutions).
#     *   Secure authentication and authorization.
#     *   Prevent cheating (e.g., basic plagiarism detection for code, though this can be a stretch goal).
# 5.  **Cost-Effectiveness:**
#     *   Optimize compute resources for grading (e.g., use spot instances, scale down idle resources).
# 6.  **Maintainability & Extensibility:**
#     *   Easy to add new programming languages to the grading engine.
#     *   Easy to add new question types or peer-review criteria.
# 7.  **Data Consistency:**
#     *   Ensure grades, submissions, and peer reviews are consistent across the system.
#
# ---
#
# **III. High-Level Architecture Considerations (What you'd discuss in an interview):**
#
# *   **Frontend:** Web application (React, Angular, Vue).
# *   **API Gateway:** For managing requests, authentication, rate limiting.
# *   **Core Services (Microservices approach likely):**
#     *   **User Service:** User profiles, authentication, authorization.
#     *   **Course/Assignment Service:** Manage course data, assignments, deadlines.
#     *   **Submission Service:** Store code submissions, manage submission state.
#     *   **Grading Orchestrator Service:** Coordinates grading jobs, puts them on a queue, collects results from workers.
#     *   **Grading Worker Pool:** A fleet of isolated, containerized environments (e.g., Docker containers running on Kubernetes) where actual code execution happens. Each worker picks a job from the queue.
#     *   **Peer Review Service:** Manages review assignments, rubric application, stores review data.
#     *   **Notification Service:** For emails, in-app notifications.
#     *   **Analytics Service:** Collects metrics, generates reports.
# *   **Databases:**
#     *   **Relational DB (PostgreSQL/MySQL):** For structured data like user info, course details, assignment metadata, submission records, peer review assignments.
#     *   **Object Storage (S3/GCS):** For storing raw code submissions, test cases, potentially large grading logs.
#     *   **NoSQL DB (MongoDB/Cassandra):** Potentially for detailed test case results, intermediate grading outputs, or highly flexible review comments.
# *   **Message Queues (Kafka/RabbitMQ/SQS):**
#     *   **Submission Queue:** Decouple submission from grading; handle bursts.
#     *   **Grading Result Queue:** Send results back to the orchestrator.
#     *   **Notification Queue:** For async notifications.
# *   **Caching (Redis/Memcached):**
#     *   Cache assignment details, popular course data, recent grading results for quick retrieval.
# *   **Security & Isolation:**
#     *   Docker containers or VMs for grading workers with strict resource limits and network isolation.
#     *   `seccomp`, `namespaces`, `cgroups` for Linux-based isolation.
#     *   Input sanitization, output filtering.
#
# ---
#
# This problem touches upon common system design challenges like distributed systems, queueing, scaling compute-intensive tasks, data storage, and paramount security considerations. Good luck designing it!
